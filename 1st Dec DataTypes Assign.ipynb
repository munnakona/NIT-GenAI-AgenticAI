# %%
print (3+2)
# Out:
# 5

# %%
print(3-1)
# Out:
# 2

# %%
print (3*2)
# Out:
# 6

# %%
print(3/2)
# Out:
# 1.5

# %%
print (3**2)
# Out:
# 9

# %%
print(3%2)
# Out:
# 1

# %%
print (3//2)
# Out:
# 1

# %% [markdown]
# ### Checking Data Types ###

# %%
print(type(10))
# Out:
# <class 'int'>

# %%
print (type(3.14))
# Out:
# <class 'float'>

# %%
print(type(1+3j))
# Out:
# <class 'complex'>

# %%
print(type('Munna'))
# Out:
# <class 'str'>

# %%
print(type([1,2,3]))
# Out:
# <class 'list'>

# %%
print(type({'name':'Munna'}))
# Out:
# <class 'dict'>

# %%
print(type({9.8,3.14,2.7}))
# Out:
# <class 'set'>

# %%
print(type((9.8,3.4,2.7)))
# Out:
# <class 'tuple'>

# %%
print(type(3 == 3))
# Out:
# <class 'bool'>

# %%
print(type(3>=3))
# Out:
# <class 'bool'>

# %% [markdown]
# #### Play with Strings #### Single Line String ##

# %%
letter = 'P'

# %%
print(letter)
# Out:
# P

# %%
print(len(letter))
# Out:
# 1

# %%
greeting = ' Hello,world'
greeting
# Out:
# ' Hello,world'

# %%
print(greeting)
# Out:
#  Hello,world

# %%
print(len(greeting))
# Out:
# 12

# %%
sentence = ' I hope your are enjoying 30 days of python challenge '
print(sentence)
# Out:
#  I hope your are enjoying 30 days of python challenge

# %% [markdown]
# # Multi Line String #

# %%
multiline_string = """I am a teacher and enjoy teaching.
I didn't find anything as rewarding as empowering people.
That is why I created 30 days of python."""
print(multiline_string)
# Out:
# I am a teacher and enjoy teaching.
# I didn't find anything as rewarding as empowering people.
# That is why I created 30 days of python.

# %% [markdown]
# ## string Concatenatio ##

# %%
first_name = 'Munna'
last_name = 'Kona'
space = ' '
full_name = first_name + space + last_name
print(full_name)
# Out:
# Munna Kona

# %%
print(len(full_name))
# Out:
# 10

# %%
print(len(first_name))
# Out:
# 5

# %%
print(len(last_name))
# Out:
# 4

# %%
print(len(first_name) < len(last_name))
# Out:
# False

# %%
print(len(full_name))
# Out:
# 10

# %% [markdown]
# # UnPacking Characters ##

# %%
language = 'Python'
a,b,c,d,e,f = language

# %%
print(a)
# Out:
# P

# %%
print(b)
# Out:
# y

# %%
print(c)
# Out:
# t

# %% [markdown]
# ### Accessing Characters in Strings by Index ##

# %%
language = 'Python'

# %%
first_letter = language[0]
print(first_letter)
# Out:
# P

# %%
second_letter = language[1]
print(second_letter)
# Out:
# y

# %%
last_index = len(language)-1
print(last_index)
# Out:
# 5

# %%
last_letter = language[last_index]
print(last_letter)
# Out:
# n

# %%
last_letter = language[-1]
print(last_letter)
# Out:
# n

# %%
second_last = language[-2]
print (second_last)
# Out:
# o

# %%
### Slicing ###

# %%
first_threee = language[0:3]
print(first_threee)
# Out:
# Pyt

# %%
last_three = language[3:6]
print(last_three)
# Out:
# hon

# %%
## Escape Sequence

# %%
print('I hope every one enjoying the python challenge.\nDo you ?')
# Out:
# I hope every one enjoying the python challenge.
# Do you ?

# %%
print('Days\tTopics\tExercises')
# Out:
# Days	Topics	Exercises

# %%
print('Day 1\t3\t5')
# Out:
# Day 1	3	5

# %%
print('Day 2\t3\t5')
# Out:
# Day 2	3	5

# %%
print('This is a black slash symbol (\\)')
# Out:
# This is a black slash symbol (\)

# %%
print('In every programming language it starts with \"Hello, World!\"')
# Out:
# In every programming language it starts with "Hello, World!"

# %%
### String Methods ##

# %%
challenge = 'thirty days of python'
print(challenge.capitalize())
# Out:
# Thirty days of python

# %%
print(challenge.count('y'))
# Out:
# 3

# %%
print(challenge.count('th'))
# Out:
# 2

# %%
print(challenge.count('a',7,14))
# Out:
# 1

# %%
# string ends with()

# %%
print(challenge.endswith('on'))
# Out:
# True

# %%
print(challenge.endswith('per'))
# Out:
# False

# %%
print(challenge.find('th'))
# Out:
# 0
