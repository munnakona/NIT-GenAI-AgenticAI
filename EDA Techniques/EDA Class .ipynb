# %%
import pandas as pd

# %%
emp = pd.read_excel(r"/Users/munna/Downloads/Rawdata.xlsx")
emp
# Out:
#      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+

# %%
pd.__version__
# Out:
# '2.2.3'

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
emp.isna().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp.info
# Out:
# <bound method DataFrame.info of      Name          Domain       Age   Location   Salary      Exp
# 0    Mike   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Teddy^         Testing    45' yr  Bangalore  10%%000       <3
# 2   Uma#r  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3    Jane     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4  Uttam*      Statistics     67-yr        NaN   30000-  5+ year
# 5     Kim             NLP      55yr      Delhi  6000^$0      10+>

# %% [markdown]
# # Data Cleaning or Data Cleansing

# %%
emp.columns
# Out:
# Index(['Name', 'Domain', 'Age', 'Location', 'Salary', 'Exp'], dtype='object')

# %%
emp['Name'] # Values have regression characters Lets remove
# Out:
# 0      Mike
# 1    Teddy^
# 2     Uma#r
# 3      Jane
# 4    Uttam*
# 5       Kim
# Name: Name, dtype: object

# %%
emp["Name"] = emp["Name"].str.replace(r'\W','',regex=True) # Replace extra characters

# %%
emp["Name"]
# Out:
# 0     Mike
# 1    Teddy
# 2     Umar
# 3     Jane
# 4    Uttam
# 5      Kim
# Name: Name, dtype: object

# %%
emp["Name"] = emp["Salary"].str.replace(r'\W','',regex=True)

# %%
emp["Name"] = emp["Location"].str.replace(r'\W','',regex=True)

# %%
emp
# Out:
#         Name          Domain       Age   Location   Salary      Exp
# 0     Mumbai   Datascience#$  34 years     Mumbai   5^00#0       2+
# 1  Bangalore         Testing    45' yr  Bangalore  10%%000       <3
# 2        NaN  Dataanalyst^^#       NaN        NaN  1$5%000   4> yrs
# 3   Hyderbad     Ana^^lytics       NaN   Hyderbad   2000^0      NaN
# 4        NaN      Statistics     67-yr        NaN   30000-  5+ year
# 5      Delhi             NLP      55yr      Delhi  6000^$0      10+

# %%
emp["Domain"] = emp["Domain"].str.replace(r'\W','',regex=True)

# %% [markdown]
# emp

# %%
emp
# Out:
#           Name       Domain       Age   Location   Salary      Exp
# 0  Datascience  Datascience  34 years     Mumbai   5^00#0       2+
# 1      Testing      Testing    45' yr  Bangalore  10%%000       <3
# 2  Dataanalyst  Dataanalyst       NaN        NaN  1$5%000   4> yrs
# 3    Analytics    Analytics       NaN   Hyderbad   2000^0      NaN
# 4   Statistics   Statistics     67-yr        NaN   30000-  5+ year
# 5          NLP          NLP      55yr      Delhi  6000^$0      10+

# %%
emp["Salary"] = emp["Salary"].str.replace(r'\W','',regex=True)

# %%
emp["Location"] = emp["Location"].str.replace(r'\W','',regex=True)

# %%
emp
# Out:
#           Name       Domain       Age   Location Salary      Exp
# 0  Datascience  Datascience  34 years     Mumbai   5000       2+
# 1      Testing      Testing    45' yr  Bangalore  10000       <3
# 2  Dataanalyst  Dataanalyst       NaN        NaN  15000   4> yrs
# 3    Analytics    Analytics       NaN   Hyderbad  20000      NaN
# 4   Statistics   Statistics     67-yr        NaN  30000  5+ year
# 5          NLP          NLP      55yr      Delhi  60000      10+

# %%
emp["Age"] = emp["Age"].str.extract('(\\d+)')
emp
# Out:
#           Name       Domain  Age   Location Salary      Exp
# 0  Datascience  Datascience   34     Mumbai   5000       2+
# 1      Testing      Testing   45  Bangalore  10000       <3
# 2  Dataanalyst  Dataanalyst  NaN        NaN  15000   4> yrs
# 3    Analytics    Analytics  NaN   Hyderbad  20000      NaN
# 4   Statistics   Statistics   67        NaN  30000  5+ year
# 5          NLP          NLP   55      Delhi  60000      10+

# %% [markdown]
# emp

# %%
emp["Exp"] = emp["Exp"].str.extract('(\\d+)')

# %%
emp
# Out:
#           Name       Domain  Age   Location Salary  Exp
# 0  Datascience  Datascience   34     Mumbai   5000    2
# 1      Testing      Testing   45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  NaN        NaN  15000    4
# 3    Analytics    Analytics  NaN   Hyderbad  20000  NaN
# 4   Statistics   Statistics   67        NaN  30000    5
# 5          NLP          NLP   55      Delhi  60000   10

# %%
emp.isnull().sum()
# Out:
# Name        0
# Domain      0
# Age         2
# Location    2
# Salary      0
# Exp         1
# dtype: int64

# %% [markdown]
# # EDA Technique

# %%
emp
# Out:
#           Name       Domain  Age   Location Salary  Exp
# 0  Datascience  Datascience   34     Mumbai   5000    2
# 1      Testing      Testing   45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  NaN        NaN  15000    4
# 3    Analytics    Analytics  NaN   Hyderbad  20000  NaN
# 4   Statistics   Statistics   67        NaN  30000    5
# 5          NLP          NLP   55      Delhi  60000   10

# %%
clean_data = emp.copy() # Lets create another copy of emp

# %%
clean_data
# Out:
#           Name       Domain  Age   Location Salary  Exp
# 0  Datascience  Datascience   34     Mumbai   5000    2
# 1      Testing      Testing   45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  NaN        NaN  15000    4
# 3    Analytics    Analytics  NaN   Hyderbad  20000  NaN
# 4   Statistics   Statistics   67        NaN  30000    5
# 5          NLP          NLP   55      Delhi  60000   10

# %% [markdown]
# # 1) EDA Technique:  Missing Value Treatment

# %%
clean_data['Age']
# Out:
# 0     34
# 1     45
# 2    NaN
# 3    NaN
# 4     67
# 5     55
# Name: Age, dtype: object

# %%
import numpy as np

# %%
clean_data['Age'] = clean_data['Age'].fillna(np.mean(pd.to_numeric(clean_data['Age']))) # Apply Mean to the Missing Data using Numpy for Numerical Value

# %%
clean_data
# Out:
#           Name       Domain    Age   Location Salary  Exp
# 0  Datascience  Datascience     34     Mumbai   5000    2
# 1      Testing      Testing     45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  50.25        NaN  15000    4
# 3    Analytics    Analytics  50.25   Hyderbad  20000  4.8
# 4   Statistics   Statistics     67        NaN  30000    5
# 5          NLP          NLP     55      Delhi  60000   10

# %%
clean_data['Exp'] = clean_data['Exp'].fillna(np.mean(pd.to_numeric(clean_data['Exp'])))

# %%
clean_data
# Out:
#           Name       Domain    Age   Location Salary  Exp
# 0  Datascience  Datascience     34     Mumbai   5000    2
# 1      Testing      Testing     45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  50.25        NaN  15000    4
# 3    Analytics    Analytics  50.25   Hyderbad  20000  4.8
# 4   Statistics   Statistics     67        NaN  30000    5
# 5          NLP          NLP     55      Delhi  60000   10

# %%
clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2          NaN
# 3     Hyderbad
# 4          NaN
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data['Location'] = clean_data['Location'].fillna(clean_data['Location'].mode()[0]) # This is applied Mode for Categorical value

# %%
clean_data['Location']
# Out:
# 0       Mumbai
# 1    Bangalore
# 2    Bangalore
# 3     Hyderbad
# 4    Bangalore
# 5        Delhi
# Name: Location, dtype: object

# %%
clean_data
# Out:
#           Name       Domain    Age   Location Salary  Exp
# 0  Datascience  Datascience     34     Mumbai   5000    2
# 1      Testing      Testing     45  Bangalore  10000    3
# 2  Dataanalyst  Dataanalyst  50.25  Bangalore  15000    4
# 3    Analytics    Analytics  50.25   Hyderbad  20000  4.8
# 4   Statistics   Statistics     67  Bangalore  30000    5
# 5          NLP          NLP     55      Delhi  60000   10
