# %%
a = 5

# %%
b = 6

# %%
a < b
# Out:
# True

# %%
a = b

# %%
a == b
# Out:
# True

# %%
a != b
# Out:
# False

# %% [markdown]
# - Logical Operator

# %%
a = 5
b = 6

# %%
a<7 or b<5
# Out:
# True

# %%
not a
# Out:
# False

# %%
not b
# Out:
# False

# %%
### Binary Number System

# %%
bin(25)
# Out:
# '0b11001'

# %%
int(ob11001)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 int(ob11001)
#
# NameError: name 'ob11001' is not defined

# %%
oct(25)
# Out:
# '0o31'

# %%
0x9
# Out:
# 9

# %%
0x1
# Out:
# 1

# %%
0xa
# Out:
# 10

# %%
0xb
# Out:
# 11

# %%
0xf
# Out:
# 15

# %%
0x1
# Out:
# 1

# %%
bin(13)
# Out:
# '0b1101'

# %%
~12
# Out:
# -13

# %%
~16
# Out:
# -17

# %%
~True
# Out:
# -2

# %%
~False
# Out:
# -1

# %%
12 & 13
# Out:
# 12

# %%
12 | 13
# Out:
# 13

# %%
12 << 2
# Out:
# 48

# %%
12 >> 2
# Out:
# 3
