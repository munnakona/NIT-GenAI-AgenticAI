# %% [markdown]
# # Data Structure #
# - list
# - tuple
# - set
# - dict

# %%
l = []
l
# Out:
# []

# %%
type(l)
# Out:
# list

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10, 10]

# %%
l
# Out:
# [10, 10]

# %%
l.append(20)
l
# Out:
# [10, 10, 20, 20]

# %%
l.clear()
l
# Out:
# []

# %%
l.append('Munna')
l
# Out:
# ['Munna', 'Munna']

# %%
l.clear()

# %%
l.append(20)
l
# Out:
# [20]

# %%
l1= l.copy()

# %%
l1
# Out:
# [20]

# %%
print(len(l))
# Out:
# 1

# %%
l.append(20)

# %%
l
# Out:
# [20, 20]

# %%
l3 = [1,2,3,4,5,6]
l3
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
l.count(2)
# Out:
# 0

# %%
l3.clear()
l3
# Out:
# []

# %%
del l3

# %%
l3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 l3
#
# NameError: name 'l3' is not defined

# %%
l.count(20)  # counting the values repeated count
# Out:
# 2

# %%
l.remove(20)

# %%
l
# Out:
# [20]

# %%
l.index(20)
# Out:
# 0

# %%
l[:]
# Out:
# [20]

# %%
l[:-1]
# Out:
# []

# %%
l = [10,20,30,40,60]

# %%
l[:-1]
# Out:
# [10, 20, 30, 40]

# %%
l[::-1]
# Out:
# [60, 40, 30, 20, 10]

# %%
l.index(20)
# Out:
# 1

# %%
l.append('Munna')

# %%
l
# Out:
# [10, 20, 30, 40, 60, 'Munna']

# %%
l.index('Munna')
# Out:
# 5

# %%
l.extend('sita')

# %%
l
# Out:
# [10, 20, 30, 40, 60, 'Munna', 's', 'i', 't', 'a']

# %%
l[1:10:3]
# Out:
# [20, 60, 'i']

# %%
l[:2:5]
# Out:
# [10]

# %%
l[2:10:3]
# 20 60 i
# Out:
# [30, 'Munna', 't']

# %%
l[:4]
# Out:
# [10, 20, 30, 40]

# %%
l
# Out:
# [10, 20, 30, 40, 60, 'Munna', 's', 'i', 't', 'a']

# %%
l[:3]
# Out:
# [10, 20, 30]

# %%
l[3:6:7]
# Out:
# [40]
