# %%
5 + 6
# Out:
# 11

# %%
10/2
# Out:
# 5.0

# %%
10//6
# Out:
# 1

# %%
_ +6
# Out:
# 7

# %%
a=4
b=5

# %%
int.__add__(a, b)
# Out:
# 9

# %%
"hello"
# Out:
# 'hello'

# %%
''hello
world"
# Out:
#   Cell In[14], line 2
#     world"
#          ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
'''hello 
world'''
# Out:
# 'hello \nworld'

# %%
a = 10
b = 12

# %%
int.__add__(a,b)
# Out:
# 22

# %%
_=10

# %%
_+12
# Out:
# 22
