# %% [markdown]
# 28th - Python Intro With

# %%
v=5

# %%
v
# Out:
# 5

# %%
id(v)
# Out:
# 4350487016

# %%
nit = 8

# %%
NIT
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 NIT
#
# NameError: name 'NIT' is not defined

# %%
nit
# Out:
# 8

# %%
8=nit
# Out:
#   Cell In[7], line 1
#     8=nit
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
nit8=4

# %%
4
# Out:
# 4

# %%
nit8
# Out:
# 4

# %%
nit$=78
nit$
# Out:
#   Cell In[11], line 1
#     nit$=78
#        ^
# SyntaxError: invalid syntax

# %%
nit_=10
nit_
# Out:
# 10

# %%
import keyword
len(keyword.kwlist)
# Out:
# 35

# %%
def =9 
def
# Out:
#   Cell In[15], line 1
#     def =9
#         ^
# SyntaxError: invalid syntax

# %%
if = 9
if
# Out:
#   Cell In[16], line 1
#     if = 9
#        ^
# SyntaxError: invalid syntax

# %%
If=12
If
# Out:
# 12

# %%
2+3
4+2
# Out:
# 6

# %%
print(2+3)
print(3+4)
# Out:
# 5
# 7
