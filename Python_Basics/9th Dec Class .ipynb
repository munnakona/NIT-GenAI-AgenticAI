# %%
l = [10,20,30,40,100]
print (l)
# Out:
# [10, 20, 30, 40, 100]

# %%
l[0]
# Out:
# 10

# %%
l[0] = 100

# %%
l
# Out:
# [100, 20, 30, 40, 100]

# %%
l.extend(20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 l.extend(20)
#
# TypeError: 'int' object is not iterable

# %%
l1 = [10000,20,50]

# %%
l.extend(l1)

# %%
l
# Out:
# [100, 20, 30, 40, 100, 10000, 20, 50]

# %%
l.pop()
# Out:
# 50

# %%
l
# Out:
# [100, 20, 30, 40, 100, 10000, 20]

# %%
l.pop(0)
# Out:
# 100

# %%
l
# Out:
# [20, 30, 40, 100, 10000, 20]

# %%
l.insert(1,55)

# %%
l
# Out:
# [20, 55, 30, 40, 100, 10000, 20]

# %%
l.remove(55)

# %%
l
# Out:
# [20, 30, 40, 100, 10000, 20]

# %%
l.reverse()

# %%
l
# Out:
# [20, 10000, 100, 40, 30, 20]

# %%
l.sort()

# %%
l
# Out:
# [20, 20, 30, 40, 100, 10000]

# %%
l1
# Out:
# [10000, 20, 50]

# %%
l2 = ["rama",20,30,40]

# %%
l2.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 l2.sort()
#
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
l.sort(reverse=False)

# %%
l
# Out:
# [20, 20, 30, 40, 100, 10000]

# %%
l.sort()

# %%
l
# Out:
# [20, 20, 30, 40, 100, 10000]
