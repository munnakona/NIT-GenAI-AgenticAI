# %%
### Print is use for Answer

# %%
a = 10
b = 20
a
b
# Out:
# 20

# %%
print(a)
# Out:
# 10

# %%
print(b)
# Out:
# 20

# %%
print(10)
print(20)
print('python')
print (10,20,'python')
# Out:
# 10
# 20
# python
# 10 20 python

# %%
num1 = 20
num2 = 30
add = num1 + num2
print(add)
# Out:
# 50

# %%
## Print Result With String

# %%
num1=20
num2=30
add=num1+num2
print('The addition of ',num1,'and',num2, 'is=', add)
# Out:
# The addition of  20 and 30 is= 50

# %%
name = 'python'
age = 20
city = 'hyd'
print('hello my name is', name,'and iam', age,'years from the',city)
# Out:
# hello my name is python and iam 20 years from the hyd

# %%
## Print Format Method

# %%
num1 = 10
num2 = 30
add = num1 + num2
print('The addition of {} and {} is= {}'.format(num1,num2,add))
# Out:
# The addition of 10 and 30 is= 40

# %%
name = 'munna'
age = 33
city = 'Hyd'
print('Hello My name is {}, and iam {} years old from {}'.format(name,age,city))
# Out:
# Hello My name is munna, and iam 33 years old from Hyd

# %%
num1 = 100
num2 = 25
num3 = 200
avg = (num1+num2+num3)/3
avg1 = round((num1+num2+num3)/3,2)
print('The average of {} , {} and {} is= {} or {}'.format(num1,num2,num3,avg,avg1))
# Out:
# The average of 100 , 25 and 200 is= 108.33333333333333 or 108.33

# %%
## More Short Method ( f string Method)

# %%
num1 = 20
num2 =30
add = num1+num2
print(f'The addition of {num1} and {num2} is= {add}')
# Out:
# The addition of 20 and 30 is= 50

# %%
# Lets combine to Print in all Methods

# %%
print('The addition of',num1,'and',num2,'is=',add)
print('The addition of {} and {} is= {}'.format(num1,num2,add))
print(f'The addition of {num1} and {num2} is = {add}')
# Out:
# The addition of 20 and 30 is= 50
# The addition of 20 and 30 is= 50
# The addition of 20 and 30 is = 50

# %%
## End Statement

# %%
print('hello',end=' ')
print('Good Morning')
# Out:
# hello Good Morning

# %%
## Separator

# %%
print('hello','hai','how','are','you',sep='! ')
# Out:
# hello! hai! how! are! you
